# %%
# %%capture
# !pip install datasets
# !pip install pydub

# %%
from datasets import load_dataset
from pydub import AudioSegment
import numpy as np
import os
import zipfile

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
raw_dataset = load_dataset("DynamicSuperb/RespiratorySoundClassification_ICBHI2017")
#raw_dataset = load_dataset("ericyxy98/pulmonary-disease-airway-lung-function-dataset")
raw_dataset
# Out:
# DatasetDict({
#     test: Dataset({
#         features: ['audio', 'file', 'instruction', 'label'],
#         num_rows: 174
#     })
# })

# %%
#raw_dataset["test"][0]
raw_dataset["csa"][13]["Participant:"]
# Out:
# 'Asthma'

# %%
def audio_segment_from_array(audio_array, sr):
    audio_int16 = np.int16(audio_array * 32767)
    audio_bytes = audio_int16.tobytes()

    audio_segment = AudioSegment(
        data=audio_bytes,
        sample_width=2,
        frame_rate=sr,
        channels=1
    )

    return audio_segment

def add_to_dict(dictionary, key, folder_path):
  if key in dictionary.keys():
    dictionary[key] += 1
  else:
    dictionary[key] = 1
    dir = os.path.join(folder_path, key)
    if not os.path.exists(dir):
      os.makedirs(dir)

def unzip_in_place(zip_path: str):
    if not zipfile.is_zipfile(zip_path):
        raise ValueError("Provided file is not a valid zip archive")

    extract_dir = os.path.dirname(zip_path)

    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_dir)

    print(f"Unzipped '{zip_path}' to '{extract_dir}'")

def walk_folders(root_dir):
    folder_dict = {}

    for folder_name in os.listdir(root_dir):
        folder_path = os.path.join(root_dir, folder_name)
        if os.path.isdir(folder_path):
            folder_dict[folder_name] = [os.path.join(folder_path, file) for file in os.listdir(folder_path)]

    return folder_dict

# %%
unzip_in_place("/content/drive/MyDrive/Pulmonary Prediction/raw_dataset/aware_raw.zip")
# Out:
# Unzipped '/content/drive/MyDrive/Pulmonary Prediction/raw_dataset/aware_raw.zip' to '/content/drive/MyDrive/Pulmonary Prediction/raw_dataset'

# %%
def process_and_save_a(raw_dataset, file_path, sr=8000, max_size=0, verbose=False):
  labels = {}

  for i, pair in enumerate(raw_dataset):
    if (max_size != 0) and (i > max_size):
      return

    samples = pair["audio"]["array"]
    sample_rate = pair["audio"]["sampling_rate"]
    label = pair["label"].lower()

    export_dir = os.path.join(file_path, label)
    add_to_dict(labels, label, export_dir)

    audio_segment = audio_segment_from_array(samples, sample_rate)
    audio_segment = audio_segment.set_frame_rate(sr).set_sample_width(1).set_channels(1)

    file_name = label + "_" + str(labels[label])  + ".wav"
    export_path = os.path.join(export_dir, file_name)
    audio_segment.export(export_path, format="wav")

    if verbose:
      print("Exported to: " + export_path)

# %%
process_and_save_a(raw_dataset['test'], "/content/drive/MyDrive/Pulmonary Prediction/dataset", 8000, 0, True)
# Out:
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/pneumonia/pneumonia_1.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/urti/urti_1.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/no potential disease detected/no potential disease detected_1.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_1.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/no potential disease detected/no potential disease detected_2.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/no potential disease detected/no potential disease detected_3.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/urti/urti_2.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_2.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/urti/urti_3.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/bronchiectasis/bronchiectasis_1.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/no potential disease detected/no potential disease detected_4.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_3.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/urti/urti_4.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/pneumonia/pneumonia_2.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_4.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/pneumonia/pneumonia_3.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/bronchiolitis/bronchiolitis_1.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/bronchiectasis/bronchiectasis_2.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/bronchiolitis/bronchiolitis_2.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/bronchiectasis/bronchiectasis_3.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_5.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/no potential disease detected/no potential disease detected_5.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_6.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/urti/urti_5.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/urti/urti_6.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_7.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/no potential disease detected/no potential disease detected_6.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_8.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_9.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/no potential disease detected/no potential disease detected_7.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/pneumonia/pneumonia_4.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_10.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_11.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_12.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_13.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_14.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/bronchiectasis/bronchiectasis_4.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/no potential disease detected/no potential disease detected_8.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/pneumonia/pneumonia_5.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/urti/urti_7.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_15.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/pneumonia/pneumonia_6.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_16.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_17.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/urti/urti_8.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/lrti/lrti_1.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/bronchiectasis/bronchiectasis_5.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_18.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_19.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/pneumonia/pneumonia_7.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/no potential disease detected/no potential disease detected_9.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_20.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/no potential disease detected/no potential disease detected_10.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/pneumonia/pneumonia_8.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/no potential disease detected/no potential disease detected_11.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_21.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/no potential disease detected/no potential disease detected_12.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/pneumonia/pneumonia_9.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_22.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/urti/urti_9.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/bronchiolitis/bronchiolitis_3.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/no potential disease detected/no potential disease detected_13.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_23.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/bronchiectasis/bronchiectasis_6.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_24.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/urti/urti_10.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/bronchiectasis/bronchiectasis_7.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/bronchiolitis/bronchiolitis_4.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_25.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_26.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_27.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/urti/urti_11.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/bronchiolitis/bronchiolitis_5.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/bronchiectasis/bronchiectasis_8.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/pneumonia/pneumonia_10.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/bronchiectasis/bronchiectasis_9.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/no potential disease detected/no potential disease detected_14.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_28.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_29.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_30.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_31.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_32.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/urti/urti_12.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/urti/urti_13.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/bronchiolitis/bronchiolitis_6.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/urti/urti_14.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_33.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/bronchiolitis/bronchiolitis_7.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/no potential disease detected/no potential disease detected_15.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_34.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/no potential disease detected/no potential disease detected_16.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_35.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/no potential disease detected/no potential disease detected_17.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_36.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/pneumonia/pneumonia_11.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/bronchiectasis/bronchiectasis_10.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_37.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/bronchiectasis/bronchiectasis_11.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_38.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/no potential disease detected/no potential disease detected_18.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/no potential disease detected/no potential disease detected_19.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/bronchiolitis/bronchiolitis_8.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/pneumonia/pneumonia_12.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/bronchiectasis/bronchiectasis_12.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/pneumonia/pneumonia_13.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/no potential disease detected/no potential disease detected_20.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/no potential disease detected/no potential disease detected_21.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/no potential disease detected/no potential disease detected_22.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/pneumonia/pneumonia_14.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/lrti/lrti_2.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/urti/urti_15.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/urti/urti_16.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_39.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_40.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/bronchiectasis/bronchiectasis_13.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/no potential disease detected/no potential disease detected_23.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_41.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/urti/urti_17.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/no potential disease detected/no potential disease detected_24.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_42.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_43.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/no potential disease detected/no potential disease detected_25.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/pneumonia/pneumonia_15.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_44.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_45.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/no potential disease detected/no potential disease detected_26.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/no potential disease detected/no potential disease detected_27.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_46.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_47.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_48.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/urti/urti_18.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/pneumonia/pneumonia_16.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/bronchiolitis/bronchiolitis_9.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_49.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_50.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/asthma/asthma_1.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/no potential disease detected/no potential disease detected_28.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_51.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/pneumonia/pneumonia_17.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/bronchiolitis/bronchiolitis_10.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/no potential disease detected/no potential disease detected_29.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/bronchiectasis/bronchiectasis_14.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/pneumonia/pneumonia_18.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/bronchiectasis/bronchiectasis_15.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/pneumonia/pneumonia_19.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/no potential disease detected/no potential disease detected_30.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/urti/urti_19.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/bronchiolitis/bronchiolitis_11.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/pneumonia/pneumonia_20.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_52.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_53.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_54.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_55.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/pneumonia/pneumonia_21.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/bronchiolitis/bronchiolitis_12.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_56.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/urti/urti_20.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/urti/urti_21.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/no potential disease detected/no potential disease detected_31.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/urti/urti_22.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/pneumonia/pneumonia_22.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/no potential disease detected/no potential disease detected_32.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/urti/urti_23.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/no potential disease detected/no potential disease detected_33.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/bronchiolitis/bronchiolitis_13.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/pneumonia/pneumonia_23.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/no potential disease detected/no potential disease detected_34.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_57.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_58.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/bronchiectasis/bronchiectasis_16.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_59.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/no potential disease detected/no potential disease detected_35.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/pneumonia/pneumonia_24.wav
# Exported to: /content/drive/MyDrive/Pulmonary Prediction/dataset/copd/copd_60.wav

# %%
def process_and_save_b(raw_dataset, input_path, file_path, sr=8000, max_size=0, verbose=False):
  labels = {}
  paths = walk_folders(input_path)
  checked = []

  for i, pair in enumerate(raw_dataset):
    if (max_size != 0) and (int(i) > max_size):
      return

    pair_id = str(pair['AWARE STUDY ID:'])

    if pair_id in checked:
      pass
    else:
      checked.append(pair_id)

    print(pair_id)
    print(paths)

    audio_segment_path = paths[pair_id]
    print(audio_segment_path)

    for path in audio_segment_path:
      audio_segment = AudioSegment.from_wav(path)
      label = pair["Participant:"].lower()

      export_dir = os.path.join(file_path, label)
      add_to_dict(labels, label, export_dir)

      audio_segment = audio_segment.set_frame_rate(sr).set_sample_width(1).set_channels(1)

      file_name = label + "_" + str(labels[label])  + ".wav"
      export_path = os.path.join(export_dir, file_name)
      audio_segment.export(export_path, format="wav")

    if verbose:
      print("Exported to: " + export_path)

# %%
    ## 8khz, 8bit, mono --- 4k of frequencies represented, 200 samples for 40hz
    ## filters needed - 2,  3,  6,  12, 25, 50, 100, 200 (+1 sample for last 3 layers)
    ##                -   (kernels)
    ##                -  (stride, test and adjust)

process_and_save_b(raw_dataset["csa"],
                   "/content/drive/MyDrive/Pulmonary Prediction/raw_dataset/aware_raw",
                   "/content/drive/MyDrive/Pulmonary Prediction/dataset",
                   8000,
                   0,
                   True)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
